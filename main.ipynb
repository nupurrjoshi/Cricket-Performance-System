# %%
import pandas as pd

# %%
data = pd.read_csv('bating_summary.csv')

# %%
data.head()
# Out:
#                   match teamInnings  battingPos             batsmanName  runs  \
# 0  Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen     3
# 1  Namibia Vs Sri Lanka     Namibia           2           Divan la Cock     9
# 2  Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton    20
# 3  Namibia Vs Sri Lanka     Namibia           4           Stephan Baard    26
# 4  Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)    20
#
#    balls  4s  6s      SR out/not_out     match_id
# 0      6   0   0   50.00         out  T20I # 1823
# 1      9   1   0  100.00         out  T20I # 1823
# 2     12   1   2  166.66         out  T20I # 1823
# 3     24   2   0  108.33         out  T20I # 1823
# 4     24   0   0   83.33         out  T20I # 1823

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (699, 11)

# %%
data.info
# Out:
# <bound method DataFrame.info of                     match teamInnings  battingPos             batsmanName  \
# 0    Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen
# 1    Namibia Vs Sri Lanka     Namibia           2           Divan la Cock
# 2    Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton
# 3    Namibia Vs Sri Lanka     Namibia           4           Stephan Baard
# 4    Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)
# ..                    ...         ...         ...                     ...
# 694   Pakistan Vs England     England           3               Phil Salt
# 695   Pakistan Vs England     England           4              Ben Stokes
# 696   Pakistan Vs England     England           5             Harry Brook
# 697   Pakistan Vs England     England           6               Moeen Ali
# 698   Pakistan Vs England     England           7        Liam Livingstone
#
# ...

# %%
data.isnull()
# Out:
#      match  teamInnings  battingPos  batsmanName   runs  balls     4s     6s  \
# 0    False        False       False        False  False  False  False  False
# 1    False        False       False        False  False  False  False  False
# 2    False        False       False        False  False  False  False  False
# 3    False        False       False        False  False  False  False  False
# 4    False        False       False        False  False  False  False  False
# ..     ...          ...         ...          ...    ...    ...    ...    ...
# 694  False        False       False        False  False  False  False  False
# 695  False        False       False        False  False  False  False  False
# 696  False        False       False        False  False  False  False  False
# 697  False        False       False        False  False  False  False  False
# 698  False        False       False        False  False  False  False  False
#
#         SR  out/not_out  match_id
# ...

# %%
data.notnull()
# Out:
#      match  teamInnings  battingPos  batsmanName  runs  balls    4s    6s  \
# 0     True         True        True         True  True   True  True  True
# 1     True         True        True         True  True   True  True  True
# 2     True         True        True         True  True   True  True  True
# 3     True         True        True         True  True   True  True  True
# 4     True         True        True         True  True   True  True  True
# ..     ...          ...         ...          ...   ...    ...   ...   ...
# 694   True         True        True         True  True   True  True  True
# 695   True         True        True         True  True   True  True  True
# 696   True         True        True         True  True   True  True  True
# 697   True         True        True         True  True   True  True  True
# 698   True         True        True         True  True   True  True  True
#
#        SR  out/not_out  match_id
# 0    True         True      True
# ...

# %%
data= data.drop_duplicates()
data
# Out:
#                     match teamInnings  battingPos             batsmanName  \
# 0    Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen
# 1    Namibia Vs Sri Lanka     Namibia           2           Divan la Cock
# 2    Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton
# 3    Namibia Vs Sri Lanka     Namibia           4           Stephan Baard
# 4    Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)
# ..                    ...         ...         ...                     ...
# 694   Pakistan Vs England     England           3               Phil Salt
# 695   Pakistan Vs England     England           4              Ben Stokes
# 696   Pakistan Vs England     England           5             Harry Brook
# 697   Pakistan Vs England     England           6               Moeen Ali
# 698   Pakistan Vs England     England           7        Liam Livingstone
#
#      runs  balls  4s  6s      SR out/not_out     match_id
# ...

# %%
data1=pd.read_csv('fact_bowling_summary.csv')
data1.head()
# Out:
#                   match bowlingTeam                  bowlerName  overs  \
# 0  Namibia Vs Sri Lanka   Sri Lanka          Maheesh Theekshana    4.0
# 1  Namibia Vs Sri Lanka   Sri Lanka         Dushmantha Chameera    4.0
# 2  Namibia Vs Sri Lanka   Sri Lanka             Pramod Madushan    4.0
# 3  Namibia Vs Sri Lanka   Sri Lanka         Chamika Karunaratne    4.0
# 4  Namibia Vs Sri Lanka   Sri Lanka  Wanindu Hasaranga de Silva    4.0
#
#    maiden  runs  wickets  economy  0s  4s  6s  wides  noBalls     match_id
# 0       0    23        1     5.75   7   0   0      2        0  T20I # 1823
# 1       0    39        1     9.75   6   3   1      2        0  T20I # 1823
# 2       0    37        2     9.25   6   3   1      0        0  T20I # 1823
# 3       0    36        1     9.00   7   3   1      1        0  T20I # 1823
# 4       0    27        1     6.75   8   1   1      0        0  T20I # 1823

# %%
type(data1)
# Out:
# pandas.core.frame.DataFrame

# %%
data1.shape
# Out:
# (500, 14)

# %%
data1=data1.drop_duplicates()
data1
# Out:
#                     match bowlingTeam                  bowlerName  overs  \
# 0    Namibia Vs Sri Lanka   Sri Lanka          Maheesh Theekshana    4.0
# 1    Namibia Vs Sri Lanka   Sri Lanka         Dushmantha Chameera    4.0
# 2    Namibia Vs Sri Lanka   Sri Lanka             Pramod Madushan    4.0
# 3    Namibia Vs Sri Lanka   Sri Lanka         Chamika Karunaratne    4.0
# 4    Namibia Vs Sri Lanka   Sri Lanka  Wanindu Hasaranga de Silva    4.0
# ..                    ...         ...                         ...    ...
# 495   Pakistan Vs England    Pakistan                 Naseem Shah    4.0
# 496   Pakistan Vs England    Pakistan                  Haris Rauf    4.0
# 497   Pakistan Vs England    Pakistan                 Shadab Khan    4.0
# 498   Pakistan Vs England    Pakistan              Mohammad Wasim    4.0
# 499   Pakistan Vs England    Pakistan              Iftikhar Ahmed    0.5
#
#      maiden  runs  wickets  economy  0s  4s  6s  wides  noBalls     match_id
# ...

# %%
data1.isnull()
# Out:
#      match  bowlingTeam  bowlerName  overs  maiden   runs  wickets  economy  \
# 0    False        False       False  False   False  False    False    False
# 1    False        False       False  False   False  False    False    False
# 2    False        False       False  False   False  False    False    False
# 3    False        False       False  False   False  False    False    False
# 4    False        False       False  False   False  False    False    False
# ..     ...          ...         ...    ...     ...    ...      ...      ...
# 495  False        False       False  False   False  False    False    False
# 496  False        False       False  False   False  False    False    False
# 497  False        False       False  False   False  False    False    False
# 498  False        False       False  False   False  False    False    False
# 499  False        False       False  False   False  False    False    False
#
#         0s     4s     6s  wides  noBalls  match_id
# ...

# %%
data1.notnull()
# Out:
#      match  bowlingTeam  bowlerName  overs  maiden  runs  wickets  economy  \
# 0     True         True        True   True    True  True     True     True
# 1     True         True        True   True    True  True     True     True
# 2     True         True        True   True    True  True     True     True
# 3     True         True        True   True    True  True     True     True
# 4     True         True        True   True    True  True     True     True
# ..     ...          ...         ...    ...     ...   ...      ...      ...
# 495   True         True        True   True    True  True     True     True
# 496   True         True        True   True    True  True     True     True
# 497   True         True        True   True    True  True     True     True
# 498   True         True        True   True    True  True     True     True
# 499   True         True        True   True    True  True     True     True
#
#        0s    4s    6s  wides  noBalls  match_id
# ...

# %%
data2=pd.read_csv('dim_players.csv')

# %%
data2.head()
# Out:
#                     name        team image    battingStyle  \
# 0  Najmul Hossain Shanto  Bangladesh   NaN   Left hand Bat
# 1          Soumya Sarkar  Bangladesh   NaN   Left hand Bat
# 2             Litton Das  Bangladesh   NaN  Right hand Bat
# 3     Shakib Al Hasan(c)  Bangladesh   NaN   Left hand Bat
# 4           Afif Hossain  Bangladesh   NaN   Left hand Bat
#
#              bowlingStyle          playingRole  \
# 0      Right arm Offbreak     Top order Batter
# 1   Right arm Medium fast  Middle order Batter
# 2                     NaN  Wicketkeeper Batter
# 3  Slow Left arm Orthodox           Allrounder
# 4      Right arm Offbreak           Allrounder
#
#                                          description
# 0  Nazmul Hossain Shanto emerged from an unusual ...
# 1  A rarity among Bangladesh allrounders, top-ord...
# 2  Liton Das is the first wicketkeeper-batsman in...
# 3  When the annals of Bangladesh cricket are sift...
# 4  Bangladesh left-hander Afif Hossain made his T...

# %%
data2.shape
# Out:
# (219, 7)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          219 non-null    object
#  1   team          219 non-null    object
#  2   image         31 non-null     object
#  3   battingStyle  219 non-null    object
#  4   bowlingStyle  199 non-null    object
#  5   playingRole   219 non-null    object
#  6   description   149 non-null    object
# dtypes: object(7)
# memory usage: 12.1+ KB

# %%
data2.describe()
# Out:
#                          name        team  \
# count                     219         219
# unique                    219          16
# top     Najmul Hossain Shanto  Bangladesh
# freq                        1          16
#
#                                                     image    battingStyle  \
# count                                                  31             219
# unique                                                 31               2
# top     https://img1.hscicdn.com/image/upload/f_auto,t...  Right hand Bat
# freq                                                    1             157
#
#               bowlingStyle playingRole  \
# count                  199         219
# unique                  17          10
# top     Right arm Offbreak      Bowler
# freq                    52          71
#
#                                               description
# count                                                 149
# unique                                                144
# ...

# %%
data2.isnull()
# Out:
#       name   team  image  battingStyle  bowlingStyle  playingRole  description
# 0    False  False   True         False         False        False        False
# 1    False  False   True         False         False        False        False
# 2    False  False   True         False          True        False        False
# 3    False  False   True         False         False        False        False
# 4    False  False   True         False         False        False        False
# ..     ...    ...    ...           ...           ...          ...          ...
# 214  False  False   True         False         False        False        False
# 215  False  False   True         False         False        False        False
# 216  False  False   True         False         False        False        False
# 217  False  False   True         False         False        False        False
# 218  False  False   True         False         False        False        False
#
# [219 rows x 7 columns]

# %%
data2.notnull()
# Out:
#      name  team  image  battingStyle  bowlingStyle  playingRole  description
# 0    True  True  False          True          True         True         True
# 1    True  True  False          True          True         True         True
# 2    True  True  False          True         False         True         True
# 3    True  True  False          True          True         True         True
# 4    True  True  False          True          True         True         True
# ..    ...   ...    ...           ...           ...          ...          ...
# 214  True  True  False          True          True         True         True
# 215  True  True  False          True          True         True         True
# 216  True  True  False          True          True         True         True
# 217  True  True  False          True          True         True         True
# 218  True  True  False          True          True         True         True
#
# [219 rows x 7 columns]

# %%
data3=pd.read_csv('summary.csv')
data3
# Out:
#            team1         team2        winner      margin     ground  \
# 0        Namibia     Sri Lanka       Namibia     55 runs    Geelong
# 1    Netherlands        U.A.E.   Netherlands   3 wickets    Geelong
# 2       Scotland   West Indies      Scotland     42 runs     Hobart
# 3        Ireland      Zimbabwe      Zimbabwe     31 runs     Hobart
# 4        Namibia   Netherlands   Netherlands   5 wickets    Geelong
# 5      Sri Lanka        U.A.E.     Sri Lanka     79 runs    Geelong
# 6        Ireland      Scotland       Ireland   6 wickets     Hobart
# 7    West Indies      Zimbabwe   West Indies     31 runs     Hobart
# 8    Netherlands     Sri Lanka     Sri Lanka     16 runs    Geelong
# 9        Namibia        U.A.E.        U.A.E.      7 runs    Geelong
# 10       Ireland   West Indies       Ireland   9 wickets     Hobart
# 11      Scotland      Zimbabwe      Zimbabwe   5 wickets     Hobart
# 12     Australia   New Zealand   New Zealand     89 runs     Sydney
# ...

# %%
data3.shape
# Out:
# (45, 7)

# %%
data.describe()
# Out:
#        battingPos        runs       balls          4s          6s
# count  699.000000  699.000000  699.000000  699.000000  699.000000
# mean     4.979971   15.978541   13.648069    1.300429    0.473534
# std      2.813628   18.709462   12.718093    1.834448    0.978465
# min      1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      3.000000    2.000000    4.000000    0.000000    0.000000
# 50%      5.000000    9.000000   10.000000    1.000000    0.000000
# 75%      7.000000   22.500000   19.000000    2.000000    1.000000
# max     11.000000  109.000000   64.000000   10.000000    8.000000

# %%
data3.info
# Out:
# <bound method DataFrame.info of            team1         team2        winner      margin     ground  \
# 0        Namibia     Sri Lanka       Namibia     55 runs    Geelong
# 1    Netherlands        U.A.E.   Netherlands   3 wickets    Geelong
# 2       Scotland   West Indies      Scotland     42 runs     Hobart
# 3        Ireland      Zimbabwe      Zimbabwe     31 runs     Hobart
# 4        Namibia   Netherlands   Netherlands   5 wickets    Geelong
# 5      Sri Lanka        U.A.E.     Sri Lanka     79 runs    Geelong
# 6        Ireland      Scotland       Ireland   6 wickets     Hobart
# 7    West Indies      Zimbabwe   West Indies     31 runs     Hobart
# 8    Netherlands     Sri Lanka     Sri Lanka     16 runs    Geelong
# 9        Namibia        U.A.E.        U.A.E.      7 runs    Geelong
# 10       Ireland   West Indies       Ireland   9 wickets     Hobart
# 11      Scotland      Zimbabwe      Zimbabwe   5 wickets     Hobart
# ...

# %%
data3.isnull()
# Out:
#     team1  team2  winner  margin  ground  matchDate  match_id
# 0   False  False   False   False   False      False     False
# 1   False  False   False   False   False      False     False
# 2   False  False   False   False   False      False     False
# 3   False  False   False   False   False      False     False
# 4   False  False   False   False   False      False     False
# 5   False  False   False   False   False      False     False
# 6   False  False   False   False   False      False     False
# 7   False  False   False   False   False      False     False
# 8   False  False   False   False   False      False     False
# 9   False  False   False   False   False      False     False
# 10  False  False   False   False   False      False     False
# 11  False  False   False   False   False      False     False
# 12  False  False   False   False   False      False     False
# 13  False  False   False   False   False      False     False
# ...

# %%
data.notnull()
# Out:
#      match  teamInnings  battingPos  batsmanName  runs  balls    4s    6s  \
# 0     True         True        True         True  True   True  True  True
# 1     True         True        True         True  True   True  True  True
# 2     True         True        True         True  True   True  True  True
# 3     True         True        True         True  True   True  True  True
# 4     True         True        True         True  True   True  True  True
# ..     ...          ...         ...          ...   ...    ...   ...   ...
# 694   True         True        True         True  True   True  True  True
# 695   True         True        True         True  True   True  True  True
# 696   True         True        True         True  True   True  True  True
# 697   True         True        True         True  True   True  True  True
# 698   True         True        True         True  True   True  True  True
#
#        SR  out/not_out  match_id
# 0    True         True      True
# ...

# %%
data3.drop_duplicates()
data3
# Out:
#            team1         team2        winner      margin     ground  \
# 0        Namibia     Sri Lanka       Namibia     55 runs    Geelong
# 1    Netherlands        U.A.E.   Netherlands   3 wickets    Geelong
# 2       Scotland   West Indies      Scotland     42 runs     Hobart
# 3        Ireland      Zimbabwe      Zimbabwe     31 runs     Hobart
# 4        Namibia   Netherlands   Netherlands   5 wickets    Geelong
# 5      Sri Lanka        U.A.E.     Sri Lanka     79 runs    Geelong
# 6        Ireland      Scotland       Ireland   6 wickets     Hobart
# 7    West Indies      Zimbabwe   West Indies     31 runs     Hobart
# 8    Netherlands     Sri Lanka     Sri Lanka     16 runs    Geelong
# 9        Namibia        U.A.E.        U.A.E.      7 runs    Geelong
# 10       Ireland   West Indies       Ireland   9 wickets     Hobart
# 11      Scotland      Zimbabwe      Zimbabwe   5 wickets     Hobart
# 12     Australia   New Zealand   New Zealand     89 runs     Sydney
# ...
